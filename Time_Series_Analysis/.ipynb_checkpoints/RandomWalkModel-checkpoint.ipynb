# %% [markdown]
# # Modeling assets with random walk

# %%
install.packages("quantmod")
# Out:
# The downloaded binary packages are in
# 	/var/folders/rh/pfd6hrw52s35skb7d44l36nr0000gn/T//RtmpE3WzFo/downloaded_packages

# %%
require(quantmod)
# Out:
# Loading required package: quantmod
#
# Loading required package: xts
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: TTR
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
# we download AAPL stock prices from Yahoo Finance
getSymbols("AAPL", src="yahoo")
# Out:
# ‘getSymbols’ currently uses auto.assign=TRUE by default, but will
# use auto.assign=FALSE in 0.5-0. You will still be able to use
# ‘loadSymbols’ to automatically load data. getOption("getSymbols.env")
# and getOption("getSymbols.auto.assign") will still be checked for
# alternate defaults.
#
# This message is shown once per session and may be disabled by setting
# options("getSymbols.warning4.0"=FALSE). See ?getSymbols for details.
# [1] "AAPL"

# %%
# there are several columns: high (Hi), low(Lo), closing price(Cl), adjusted closing price(Ad)
head(Ad(AAPL))
# Out:
#            AAPL.Adjusted
# 2007-01-03      2.573566
# 2007-01-04      2.630688
# 2007-01-05      2.611954
# 2007-01-08      2.624853
# 2007-01-09      2.842900
# 2007-01-10      2.978950

# %%
# we want to plot the adjusted closing prices
plot(Ad(AAPL))
# Out:
# plot without title

# %%
# if the process is indeed a random walk: the diff series
# has n serial correlation !!!
acf(diff(Ad(AAPL)), na.action=na.omit)
# Out:
# Plot with title “Series  diff(Ad(AAPL))”

# %%
# we download S&P500 stock prices from Yahoo Finance
getSymbols("^GSPC", src="yahoo")
# Out:
# [1] "^GSPC"

# %%
acf(diff(Ad(GSPC)), na.action=na.omit)
# Out:
# Plot with title “Series  diff(Ad(GSPC))”
