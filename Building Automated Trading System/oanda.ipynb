# %%
# OANDA API testing

import oandapyV20
import oandapyV20.endpoints.instruments as instruments
import oandapyV20.endpoints.pricing as pricing
import oandapyV20.endpoints.accounts as accounts
import oandapyV20.endpoints.orders as orders
import oandapyV20.endpoints.trades as trades
import pandas as pd

# %%
#initiating API connection and defining trade parameters
token_path = "/Users/oozdal/keys/oanda.txt"
TOKEN = open(token_path,'r').read()
TOKEN = TOKEN[0:65]
client = oandapyV20.API(access_token=TOKEN, environment="practice")  # open(token_path,'r').read()

# %%
#get historical data (candles)
params = {"count": 150,"granularity": "M5"} #granularity can be in seconds S5 - S30, minutes M1 - M30, hours H1 - H12, days D, weeks W or months M
candles = instruments.InstrumentsCandles(instrument="USD_JPY",params=params)
client.request(candles)
print(candles.response)
# Out:
# {'instrument': 'USD_JPY', 'granularity': 'M5', 'candles': [{'complete': True, 'volume': 163, 'time': '2021-05-14T08:00:00.000000000Z', 'mid': {'o': '109.390', 'h': '109.493', 'l': '109.370', 'c': '109.488'}}, {'complete': True, 'volume': 188, 'time': '2021-05-14T08:05:00.000000000Z', 'mid': {'o': '109.486', 'h': '109.496', 'l': '109.324', 'c': '109.493'}}, {'complete': True, 'volume': 173, 'time': '2021-05-14T08:10:00.000000000Z', 'mid': {'o': '109.494', 'h': '109.508', 'l': '109.326', 'c': '109.499'}}, {'complete': True, 'volume': 183, 'time': '2021-05-14T08:15:00.000000000Z', 'mid': {'o': '109.500', 'h': '109.505', 'l': '109.302', 'c': '109.474'}}, {'complete': True, 'volume': 246, 'time': '2021-05-14T08:20:00.000000000Z', 'mid': {'o': '109.315', 'h': '109.481', 'l': '109.286', 'c': '109.440'}}, {'complete': True, 'volume': 215, 'time': '2021-05-14T08:25:00.000000000Z', 'mid': {'o': '109.438', 'h': '109.451', 'l': '109.264', 'c': '109.432'}}, {'complete': True, 'volume': 152, 'time': '2021-05-14T08:30:00.000000000Z', 'mid': {'o': '109.434', 'h': '109.456', 'l': '109.260', 'c': '109.456'}}, {'complete': True, 'volume': 159, 'time': '2021-05-14T08:35:00.000000000Z', 'mid': {'o': '109.454', 'h': '109.458', 'l': '109.270', 'c': '109.429'}}, {'complete': True, 'volume': 183, 'time': '2021-05-14T08:40:00.000000000Z', 'mid': {'o': '109.295', 'h': '109.436', 'l': '109.292', 'c': '109.425'}}, {'complete': True, 'volume': 182, 'time': '2021-05-14T08:45:00.000000000Z', 'mid': {'o': '109.298', 'h': '109.429', 'l': '109.290', 'c': '109.418'}}, {'complete': True, 'volume': 182, 'time': '2021-05-14T08:50:00.000000000Z', 'mid': {'o': '109.420', 'h': '109.426', 'l': '109.290', 'c': '109.398'}}, {'complete': True, 'volume': 200, 'time': '2021-05-14T08:55:00.000000000Z', 'mid': {'o': '109.400', 'h': '109.404', 'l': '109.260', 'c': '109.397'}}, {'complete': True, 'volume': 196, 'time': '2021-05-14T09:00:00.000000000Z', 'mid': {'o': '109.396', 'h': '109.398', 'l': '109.278', 'c': '109.378'}}, {'complete': True, 'volume': 204, 'time': '2021-05-14T09:05:00.000000000Z', 'mid': {'o': '109.380', 'h': '109.384', 'l': '109.274', 'c': '109.364'}}, {'complete': True, 'volume': 202, 'time': '2021-05-14T09:10:00.000000000Z', 'mid': {'o': '109.366', 'h': '109.378', 'l': '109.249', 'c': '109.368'}}, {'complete': True, 'volume': 200, 'time': '2021-05-14T09:15:00.000000000Z', 'mid': {'o': '109.366', 'h': '109.383', 'l': '109.277', 'c': '109.352'}}, {'complete': True, 'volume': 224, 'time': '2021-05-14T09:20:00.000000000Z', 'mid': {'o': '109.350', 'h': '109.370', 'l': '109.308', 'c': '109.363'}}, {'complete': True, 'volume': 179, 'time': '2021-05-14T09:25:00.000000000Z', 'mid': {'o': '109.364', 'h': '109.392', 'l': '109.333', 'c': '109.390'}}, {'complete': True, 'volume': 180, 'time': '2021-05-14T09:30:00.000000000Z', 'mid': {'o': '109.388', 'h': '109.396', 'l': '109.332', 'c': '109.393'}}, {'complete': True, 'volume': 205, 'time': '2021-05-14T09:35:00.000000000Z', 'mid': {'o': '109.392', 'h': '109.397', 'l': '109.320', 'c': '109.375'}}, {'complete': True, 'volume': 256, 'time': '2021-05-14T09:40:00.000000000Z', 'mid': {'o': '109.376', 'h': '109.378', 'l': '109.335', 'c': '109.375'}}, {'complete': True, 'volume': 218, 'time': '2021-05-14T09:45:00.000000000Z', 'mid': {'o': '109.373', 'h': '109.386', 'l': '109.344', 'c': '109.380'}}, {'complete': True, 'volume': 219, 'time': '2021-05-14T09:50:00.000000000Z', 'mid': {'o': '109.378', 'h': '109.381', 'l': '109.334', 'c': '109.352'}}, {'complete': True, 'volume': 242, 'time': '2021-05-14T09:55:00.000000000Z', 'mid': {'o': '109.348', 'h': '109.376', 'l': '109.329', 'c': '109.370'}}, {'complete': True, 'volume': 214, 'time': '2021-05-14T10:00:00.000000000Z', 'mid': {'o': '109.353', 'h': '109.403', 'l': '109.353', 'c': '109.396'}}, {'complete': True, 'volume': 185, 'time': '2021-05-14T10:05:00.000000000Z', 'mid': {'o': '109.367', 'h': '109.406', 'l': '109.344', 'c': '109.402'}}, {'complete': True, 'volume': 170, 'time': ...

# %%
ohlc_dict = candles.response["candles"]
ohlc = pd.DataFrame(ohlc_dict)
ohlc
# Out:
#      complete  volume                            time  \
# 0        True     163  2021-05-14T08:00:00.000000000Z
# 1        True     188  2021-05-14T08:05:00.000000000Z
# 2        True     173  2021-05-14T08:10:00.000000000Z
# 3        True     183  2021-05-14T08:15:00.000000000Z
# 4        True     246  2021-05-14T08:20:00.000000000Z
# ..        ...     ...                             ...
# 145      True      45  2021-05-14T20:05:00.000000000Z
# 146      True      56  2021-05-14T20:10:00.000000000Z
# 147      True      24  2021-05-14T20:15:00.000000000Z
# 148      True      56  2021-05-14T20:20:00.000000000Z
# 149     False      18  2021-05-14T20:25:00.000000000Z
#
#                                                    mid
# 0    {'o': '109.390', 'h': '109.493', 'l': '109.370...
# 1    {'o': '109.486', 'h': '109.496', 'l': '109.324...
# 2    {'o': '109.494', 'h': '109.508', 'l': '109.326...
# 3    {'o': '109.500', 'h': '109.505', 'l': '109.302...
# 4    {'o': '109.315', 'h': '109.481', 'l': '109.286...
# ..                                                 ...
# 145  {'o': '109.347', 'h': '109.353', 'l': '109.347...
# 146  {'o': '109.354', 'h': '109.357', 'l': '109.350...
# 147  {'o': '109.353', 'h': '109.362', 'l': '109.351...
# 148  {'o': '109.360', 'h': '109.367', 'l': '109.353...
# 149  {'o': '109.366', 'h': '109.366', 'l': '109.362...
#
# [150 rows x 4 columns]

# %%
ohlc_df = ohlc.mid.dropna().apply(pd.Series)
ohlc_df
# Out:
#            o        h        l        c
# 0    109.390  109.493  109.370  109.488
# 1    109.486  109.496  109.324  109.493
# 2    109.494  109.508  109.326  109.499
# 3    109.500  109.505  109.302  109.474
# 4    109.315  109.481  109.286  109.440
# ..       ...      ...      ...      ...
# 145  109.347  109.353  109.347  109.352
# 146  109.354  109.357  109.350  109.352
# 147  109.353  109.362  109.351  109.362
# 148  109.360  109.367  109.353  109.364
# 149  109.366  109.366  109.362  109.364
#
# [150 rows x 4 columns]

# %%
ohlc_df["volume"] = ohlc["volume"]
ohlc_df.index = ohlc["time"]
ohlc_df
# Out:
#                                       o        h        l        c  volume
# time
# 2021-05-14T08:00:00.000000000Z  109.390  109.493  109.370  109.488     163
# 2021-05-14T08:05:00.000000000Z  109.486  109.496  109.324  109.493     188
# 2021-05-14T08:10:00.000000000Z  109.494  109.508  109.326  109.499     173
# 2021-05-14T08:15:00.000000000Z  109.500  109.505  109.302  109.474     183
# 2021-05-14T08:20:00.000000000Z  109.315  109.481  109.286  109.440     246
# ...                                 ...      ...      ...      ...     ...
# 2021-05-14T20:05:00.000000000Z  109.347  109.353  109.347  109.352      45
# 2021-05-14T20:10:00.000000000Z  109.354  109.357  109.350  109.352      56
# 2021-05-14T20:15:00.000000000Z  109.353  109.362  109.351  109.362      24
# 2021-05-14T20:20:00.000000000Z  109.360  109.367  109.353  109.364      56
# 2021-05-14T20:25:00.000000000Z  109.366  109.366  109.362  109.364      18
#
# [150 rows x 5 columns]

# %%
ohlc_df = ohlc_df.apply(pd.to_numeric)
ohlc_df
# Out:
#                                       o        h        l        c  volume
# time
# 2021-05-14T08:00:00.000000000Z  109.390  109.493  109.370  109.488     163
# 2021-05-14T08:05:00.000000000Z  109.486  109.496  109.324  109.493     188
# 2021-05-14T08:10:00.000000000Z  109.494  109.508  109.326  109.499     173
# 2021-05-14T08:15:00.000000000Z  109.500  109.505  109.302  109.474     183
# 2021-05-14T08:20:00.000000000Z  109.315  109.481  109.286  109.440     246
# ...                                 ...      ...      ...      ...     ...
# 2021-05-14T20:05:00.000000000Z  109.347  109.353  109.347  109.352      45
# 2021-05-14T20:10:00.000000000Z  109.354  109.357  109.350  109.352      56
# 2021-05-14T20:15:00.000000000Z  109.353  109.362  109.351  109.362      24
# 2021-05-14T20:20:00.000000000Z  109.360  109.367  109.353  109.364      56
# 2021-05-14T20:25:00.000000000Z  109.366  109.366  109.362  109.364      18
#
# [150 rows x 5 columns]

# %%
#streaming data
params = {"instruments": "USD_JPY"}
account_id = "101-002-19239803-001"
r = pricing.PricingInfo(accountID=account_id, params=params)
i=0
while i <=10:
    rv = client.request(r)
    print("Time=",rv["time"])
    print("bid=",rv["prices"][0]["closeoutBid"])
    print("ask=",rv["prices"][0]["closeoutAsk"])
    print("*******************")
    i+=1
# Out:
# Time= 2021-05-14T20:26:12.024805793Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.024805793Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.130236779Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.130236779Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.130236779Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.130236779Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.130236779Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.433571580Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.535000616Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.613341634Z
# bid= 109.357
# ask= 109.372
# *******************
# Time= 2021-05-14T20:26:12.634430435Z
# bid= 109.357
# ask= 109.372
# *******************

# %%
#trading account details
r = accounts.AccountDetails(accountID=account_id)
client.request(r)
print(r.response)
# Out:
# {'account': {'guaranteedStopLossOrderMode': 'DISABLED', 'hedgingEnabled': False, 'id': '101-002-19239803-001', 'createdTime': '2021-05-11T03:45:54.218406680Z', 'currency': 'CAD', 'createdByUserID': 19239803, 'alias': 'Primary', 'marginRate': '0.02', 'lastTransactionID': '11', 'balance': '100000.0000', 'openTradeCount': 1, 'openPositionCount': 1, 'pendingOrderCount': 1, 'pl': '0.0000', 'resettablePL': '0.0000', 'resettablePLTime': '0', 'financing': '0.0000', 'commission': '0.0000', 'dividendAdjustment': '0', 'guaranteedExecutionFees': '0.0000', 'orders': [{'id': '9', 'createTime': '2021-05-14T20:25:34.252041627Z', 'type': 'STOP_LOSS', 'tradeID': '8', 'price': '109.567', 'timeInForce': 'GTC', 'triggerCondition': 'DEFAULT', 'state': 'PENDING'}], 'positions': [{'instrument': 'USD_JPY', 'long': {'units': '0', 'pl': '0.0000', 'resettablePL': '0.0000', 'financing': '0.0000', 'dividendAdjustment': '0.0000', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '0.0000'}, 'short': {'units': '-100', 'averagePrice': '109.356', 'pl': '0.0000', 'resettablePL': '0.0000', 'financing': '0.0000', 'dividendAdjustment': '0.0000', 'guaranteedExecutionFees': '0.0000', 'tradeIDs': ['8'], 'unrealizedPL': '-0.0178'}, 'pl': '0.0000', 'resettablePL': '0.0000', 'financing': '0.0000', 'commission': '0.0000', 'dividendAdjustment': '0.0000', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '-0.0178', 'marginUsed': '5.4500'}], 'trades': [{'id': '8', 'instrument': 'USD_JPY', 'price': '109.356', 'openTime': '2021-05-14T20:25:34.252041627Z', 'initialUnits': '-100', 'initialMarginRequired': '5.4500', 'state': 'OPEN', 'currentUnits': '-100', 'realizedPL': '0.0000', 'financing': '0.0000', 'dividendAdjustment': '0.0000', 'stopLossOrderID': '9', 'unrealizedPL': '-0.0178', 'marginUsed': '5.4500'}], 'unrealizedPL': '-0.0178', 'NAV': '99999.9822', 'marginUsed': '5.4500', 'marginAvailable': '99994.5323', 'positionValue': '121.1120', 'marginCloseoutUnrealizedPL': '-0.0089', 'marginCloseoutNAV': '99999.9911', 'marginCloseoutMarginUsed': '5.4500', 'marginCloseoutPositionValue': '121.1120', 'marginCloseoutPercent': '0.00003', 'withdrawalLimit': '99994.5323', 'marginCallMarginUsed': '5.4500', 'marginCallPercent': '0.00005'}, 'lastTransactionID': '11'}

# %%
#trading account summary
r = accounts.AccountSummary(accountID=account_id)
client.request(r)
print(r.response)
# Out:
# {'account': {'guaranteedStopLossOrderMode': 'DISABLED', 'hedgingEnabled': False, 'id': '101-002-19239803-001', 'createdTime': '2021-05-11T03:45:54.218406680Z', 'currency': 'CAD', 'createdByUserID': 19239803, 'alias': 'Primary', 'marginRate': '0.02', 'lastTransactionID': '11', 'balance': '100000.0000', 'openTradeCount': 1, 'openPositionCount': 1, 'pendingOrderCount': 1, 'pl': '0.0000', 'resettablePL': '0.0000', 'resettablePLTime': '0', 'financing': '0.0000', 'commission': '0.0000', 'dividendAdjustment': '0', 'guaranteedExecutionFees': '0.0000', 'unrealizedPL': '-0.0178', 'NAV': '99999.9822', 'marginUsed': '5.4500', 'marginAvailable': '99994.5323', 'positionValue': '121.1120', 'marginCloseoutUnrealizedPL': '-0.0089', 'marginCloseoutNAV': '99999.9911', 'marginCloseoutMarginUsed': '5.4500', 'marginCloseoutPositionValue': '121.1120', 'marginCloseoutPercent': '0.00003', 'withdrawalLimit': '99994.5323', 'marginCallMarginUsed': '5.4500', 'marginCallPercent': '0.00005'}, 'lastTransactionID': '11'}

# %%
#orders
data = {
        "order": {
        "price": "1.15",
        "stopLossOnFill": {
        "timeInForce": "GTC",
        "price": "1.2"
                          },
        "timeInForce": "FOK",
        "instrument": "USD_CAD",
        "units": "-100",
        "type": "MARKET",
        "positionFill": "DEFAULT"
                }
        }

r = orders.OrderCreate(accountID=account_id, data=data)
client.request(r)
# Out:
# {'orderCreateTransaction': {'id': '12',
#   'accountID': '101-002-19239803-001',
#   'userID': 19239803,
#   'batchID': '12',
#   'requestID': '60842262875024025',
#   'time': '2021-05-14T20:26:15.169075762Z',
#   'type': 'MARKET_ORDER',
#   'instrument': 'USD_CAD',
#   'units': '-100',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'stopLossOnFill': {'price': '1.20000', 'timeInForce': 'GTC'},
#   'reason': 'CLIENT_ORDER'},
#  'orderCancelTransaction': {'id': '13',
#   'accountID': '101-002-19239803-001',
#   'userID': 19239803,
#   'batchID': '12',
#   'requestID': '60842262875024025',
#   'time': '2021-05-14T20:26:15.169075762Z',
#   'type': 'ORDER_CANCEL',
#   'orderID': '12',
#   'reason': 'STOP_LOSS_ON_FILL_LOSS'},
#  'relatedTransactionIDs': ['12', '13'],
#  'lastTransactionID': '13'}

# %%
#slightly more sophisticated way of placing an order
def ATR(DF,n):
    "function to calculate True Range and Average True Range"
    df = DF.copy()
    df['H-L']=abs(df['h']-df['l'])
    df['H-PC']=abs(df['h']-df['c'].shift(1))
    df['L-PC']=abs(df['l']-df['c'].shift(1))
    df['TR']=df[['H-L','H-PC','L-PC']].max(axis=1,skipna=False)
    df['ATR'] = df['TR'].rolling(n).mean()
    #df['ATR'] = df['TR'].ewm(span=n,adjust=False,min_periods=n).mean()
    df2 = df.drop(['H-L','H-PC','L-PC'],axis=1)
    return round(df2["ATR"][-1],2)


def market_order(instrument,units,sl):
    """units can be positive or negative, stop loss (in pips) added/subtracted to price """
    params = {"instruments": instrument}
    account_id = "101-002-19239803-001"
    r = pricing.PricingInfo(accountID=account_id, params=params)
    rv = client.request(r)
    if units > 0:
        price = float(rv["prices"][0]["closeoutAsk"])
        st_ls = price - sl
    else:
        price = float(rv["prices"][0]["closeoutBid"])
        st_ls = price + sl
    
    data = {
            "order": {
            "price": "",
            "stopLossOnFill": {
            "timeInForce": "GTC",
            "price": str(st_ls)
                              },
            "timeInForce": "FOK",
            "instrument": str(instrument),
            "units": str(units),
            "type": "MARKET",
            "positionFill": "DEFAULT"
                    }
            }
    return data

# %%
r = orders.OrderCreate(accountID=account_id, data=market_order("USD_JPY",-100,3*ATR(ohlc_df,120)))
client.request(r)
# Out:
# {'orderCreateTransaction': {'id': '14',
#   'accountID': '101-002-19239803-001',
#   'userID': 19239803,
#   'batchID': '14',
#   'requestID': '60842262883415292',
#   'time': '2021-05-14T20:26:17.154185764Z',
#   'type': 'MARKET_ORDER',
#   'instrument': 'USD_JPY',
#   'units': '-100',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'stopLossOnFill': {'price': '109.537', 'timeInForce': 'GTC'},
#   'reason': 'CLIENT_ORDER'},
#  'orderFillTransaction': {'id': '15',
#   'accountID': '101-002-19239803-001',
#   'userID': 19239803,
#   'batchID': '14',
#   'requestID': '60842262883415292',
#   'time': '2021-05-14T20:26:17.154185764Z',
#   'type': 'ORDER_FILL',
#   'orderID': '14',
#   'instrument': 'USD_JPY',
#   'units': '-100',
#   'requestedUnits': '-100',
#   'price': '109.357',
#   'pl': '0.0000',
#   'quotePL': '0',
#   'financing': '0.0000',
#   'baseFinancing': '0',
#   'commission': '0.0000',
#   'accountBalance': '100000.0000',
#   'gainQuoteHomeConversionFactor': '0.01101888727',
#   'lossQuoteHomeConversionFactor': '0.011129629855',
#   'guaranteedExecutionFee': '0.0000',
#   'quoteGuaranteedExecutionFee': '0',
#   'halfSpreadCost': '0.0083',
#   'fullVWAP': '109.357',
#   'reason': 'MARKET_ORDER',
#   'tradeOpened': {'price': '109.357',
#    'tradeID': '15',
#    'units': '-100',
#    'guaranteedExecutionFee': '0.0000',
#    'quoteGuaranteedExecutionFee': '0',
#    'halfSpreadCost': '0.0083',
#    'initialMarginRequired': '5.4500'},
#   'fullPrice': {'closeoutBid': '109.357',
#    'closeoutAsk': '109.372',
#    'timestamp': '2021-05-14T20:26:04.909268950Z',
#    'bids': [{'price': '109.357', 'liquidity': '10000000'}],
#    'asks': [{'price': '109.372', 'liquidity': '10000000'}]},
#   'homeConversionFactors': {'gainQuoteHome': {'factor': '0.01101888726973'},
#    'lossQuoteHome': {'factor': '0.01112962985535'},
#    'gainBaseHome': {'factor': '1.20506440'},
#    'lossBaseHome': {'factor': '1.21717560'}}},
#  'relatedTransactionIDs': ['14', '15', '16'],
#  'lastTransactionID': '16'}

# %%
#check trades
r = trades.OpenTrades(accountID=account_id)
client.request(r)
#client.request(r)['trades'][0]['currentUnits']
# Out:
# {'trades': [{'id': '15',
#    'instrument': 'USD_JPY',
#    'price': '109.357',
#    'openTime': '2021-05-14T20:26:17.154185764Z',
#    'initialUnits': '-100',
#    'initialMarginRequired': '5.4500',
#    'state': 'OPEN',
#    'currentUnits': '-100',
#    'realizedPL': '0.0000',
#    'financing': '0.0000',
#    'dividendAdjustment': '0.0000',
#    'unrealizedPL': '-0.0045',
#    'marginUsed': '5.4502',
#    'stopLossOrder': {'id': '16',
#     'createTime': '2021-05-14T20:26:17.154185764Z',
#     'type': 'STOP_LOSS',
#     'tradeID': '15',
#     'price': '109.537',
#     'timeInForce': 'GTC',
#     'triggerCondition': 'DEFAULT',
#     'state': 'PENDING'}},
#   {'id': '8',
#    'instrument': 'USD_JPY',
#    'price': '109.356',
#    'openTime': '2021-05-14T20:25:34.252041627Z',
#    'initialUnits': '-100',
#    'initialMarginRequired': '5.4500',
#    'state': 'OPEN',
#    'currentUnits': '-100',
#    'realizedPL': '0.0000',
#    'financing': '0.0000',
#    'dividendAdjustment': '0.0000',
#    'unrealizedPL': '-0.0056',
#    'marginUsed': '5.4502',
#    'stopLossOrder': {'id': '9',
#     'createTime': '2021-05-14T20:25:34.252041627Z',
#     'type': 'STOP_LOSS',
#     'tradeID': '8',
#     'price': '109.567',
#     'timeInForce': 'GTC',
#     'triggerCondition': 'DEFAULT',
#     'state': 'PENDING'}}],
#  'lastTransactionID': '16'}
