# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
tickers = ["AAPL","MSFT"] #list of tickers whose financial data needs to be extracted
financial_dir = {}

# %%
for ticker in tickers:
    #getting balance sheet data from yahoo finance for the given ticker
    temp_dir = {}
    url = 'https://in.finance.yahoo.com/quote/'+ticker+'/balance-sheet?p='+ticker
    page = requests.get(url)
    page_content = page.content
    soup = BeautifulSoup(page_content,'html.parser')
    tabl = soup.find_all("table")
    for t in tabl:
        rows = t.find_all("tr")
        for row in rows:
            if len(row.get_text(separator='|').split("|")[0:2])>1:
                temp_dir[row.get_text(separator='|').split("|")[0]]=row.get_text(separator='|').split("|")[1]
    
    #getting income statement data from yahoo finance for the given ticker
    url = 'https://in.finance.yahoo.com/quote/'+ticker+'/financials?p='+ticker
    page = requests.get(url)
    page_content = page.content
    soup = BeautifulSoup(page_content,'html.parser')
    tabl = soup.find_all("table")
    for t in tabl:
        rows = t.find_all("tr")
        for row in rows:
            if len(row.get_text(separator='|').split("|")[0:2])>1:
                temp_dir[row.get_text(separator='|').split("|")[0]]=row.get_text(separator='|').split("|")[1]
    
    #getting cashflow statement data from yahoo finance for the given ticker
    url = 'https://in.finance.yahoo.com/quote/'+ticker+'/cash-flow?p='+ticker
    page = requests.get(url)
    page_content = page.content
    soup = BeautifulSoup(page_content,'html.parser')
    tabl = soup.find_all("table")
    for t in tabl:
        rows = t.find_all("tr")
        for row in rows:
            if len(row.get_text(separator='|').split("|")[0:2])>1:
                temp_dir[row.get_text(separator='|').split("|")[0]]=row.get_text(separator='|').split("|")[1]
    
    #getting key statistics data from yahoo finance for the given ticker
    url = 'https://in.finance.yahoo.com/quote/'+ticker+'/key-statistics?p='+ticker
    page = requests.get(url)
    page_content = page.content
    soup = BeautifulSoup(page_content,'html.parser')
    tabl = soup.find_all("table")
    for t in tabl:
        rows = t.find_all("tr")
        for row in rows:
            if len(row.get_text(separator='|').split("|")[0:2])>0:
                temp_dir[row.get_text(separator='|').split("|")[0]]=row.get_text(separator='|').split("|")[-1]    
    
    #combining all extracted information with the corresponding ticker
    financial_dir[ticker] = temp_dir

# %%
#storing information in pandas dataframe
combined_financials = pd.DataFrame(financial_dir)
combined_financials.dropna(axis=1,inplace=True)
tickers = combined_financials.columns

# %%
combined_financials
# Out:
#                                                     AAPL         MSFT
# Market cap (intra-day)                             2.22T        1.94T
# Enterprise value                                   2.28T        1.92T
# Trailing P/E                                       35.79        38.34
# Forward P/E                                        28.07        31.79
# PEG Ratio (5 yr expected)                           2.01         1.72
# Price/sales                                         7.53        12.65
# Price/book                                         33.52        14.90
# Enterprise value/revenue                            7.74        12.50
# Enterprise value/EBITDA                            26.73        26.73
# Beta (5Y monthly)                                   1.22         0.79
# 52-week change                                    94.16%       52.01%
# S&P500 52-week change                             49.17%       49.17%
# 52-week high                                      145.09       261.78
# 52-week low                                        68.72       169.39
# 50-day moving average                             125.27       241.99
# 200-day moving average                            125.05       226.73
# Avg vol (3-month)                                105.39M        29.7M
# Avg vol (10-day)                                  87.73M       23.94M
# Shares outstanding                                16.79B        7.56B
# Implied shares outstanding                           N/A          N/A
# Float                                             16.77B        7.43B
# % held by insiders                                 0.08%        0.07%
# % held by institutions                            59.80%       72.22%
# Shares short (30-Mar-2021)                       101.48M       48.43M
# Short ratio (30-Mar-2021)                           0.88         1.54
# Short % of float (30-Mar-2021)                     0.60%        0.64%
# Short % of shares outstanding (30-Mar-2021)        0.60%        0.64%
# Shares short (prior month 25-Feb-2021)            100.8M       41.63M
# Forward annual dividend rate                        0.82         2.24
# Forward annual dividend yield                      0.61%        0.86%
# Trailing annual dividend rate                       0.81         2.14
# Trailing annual dividend yield                     0.60%        0.82%
# 5-year average dividend yield                       1.39         1.66
# Payout ratio                                      21.77%       31.15%
# Dividend date                                10-Feb-2021  09-Jun-2021
# Ex-dividend date                             04-Feb-2021  18-May-2021
# Last split factor                                    4:1          2:1
# Last split date                              30-Aug-2020  17-Feb-2003
# Fiscal year ends                             25-Sep-2020  29-Jun-2020
# Most-recent quarter                          25-Dec-2020  30-Dec-2020
# Profit margin                                     21.74%       33.47%
# Operating margin                                  25.25%       39.24%
# Return on assets                                  13.36%       12.81%
# Return on equity                                  82.09%       42.70%
# Revenue                                          294.14B      153.28B
# Revenue per share                                  17.13        20.23
# Quarterly revenue growth                          21.40%       16.70%
# Gross profit                                     104.96B       96.94B
# EBITDA                                            85.16B       71.69B
# Net income avi to common                          63.93B       51.31B
# Diluted EPS                                         3.69         6.71
# Quarterly earnings growth                         29.30%       32.70%
# Total cash                                        76.83B      131.99B
# Total cash per share                                4.58         17.5
# Total debt                                       112.04B       82.78B
# Total debt/equity                                 169.19        63.56
# Current ratio                                       1.16         2.58
# Book value per share                                3.94        17.26
# Operating cash flow                               88.92B       68.03B
# Levered free cash flow                            66.89B       34.79B

# %%
tickers
# Out:
# Index(['AAPL', 'MSFT'], dtype='object')
